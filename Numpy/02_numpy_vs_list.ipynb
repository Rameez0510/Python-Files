# %%
# %time [j**5 for j in range(1,999)] #numpy makes program faster than from list
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# [1,
#  32,
#  243,
#  1024,
#  3125,
#  7776,
#  16807,
#  32768,
#  59049,
#  100000,
#  161051,
#  248832,
#  371293,
#  537824,
#  759375,
#  1048576,
#  1419857,
#  1889568,
#  2476099,
#  3200000,
#  4084101,
#  5153632,
#  6436343,
#  7962624,
#  9765625,
#  11881376,
#  14348907,
#  17210368,
#  20511149,
#  24300000,
#  28629151,
#  33554432,
#  39135393,
#  45435424,
#  52521875,
#  60466176,
#  69343957,
#  79235168,
#  90224199,
#  102400000,
#  115856201,
#  130691232,
#  147008443,
#  164916224,
#  184528125,
#  205962976,
#  229345007,
#  254803968,
#  282475249,
#  312500000,
#  345025251,
#  380204032,
#  418195493,
#  459165024,
#  503284375,
#  550731776,
#  601692057,
#  656356768,
#  714924299,
#  777600000,
#  844596301,
#  916132832,
#  992436543,
#  1073741824,
#  1160290625,
#  1252332576,
#  1350125107,
#  1453933568,
#  1564031349,
#  1680700000,
#  1804229351,
#  1934917632,
#  2073071593,
#  2219006624,
# ...

# %%
import numpy as np
# %time np.arange(1,999)**5
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns
# array([          1,          32,         243,        1024,        3125,
#               7776,       16807,       32768,       59049,      100000,
#             161051,      248832,      371293,      537824,      759375,
#            1048576,     1419857,     1889568,     2476099,     3200000,
#            4084101,     5153632,     6436343,     7962624,     9765625,
#           11881376,    14348907,    17210368,    20511149,    24300000,
#           28629151,    33554432,    39135393,    45435424,    52521875,
#           60466176,    69343957,    79235168,    90224199,   102400000,
#          115856201,   130691232,   147008443,   164916224,   184528125,
#          205962976,   229345007,   254803968,   282475249,   312500000,
#          345025251,   380204032,   418195493,   459165024,   503284375,
#          550731776,   601692057,   656356768,   714924299,   777600000,
# ...
